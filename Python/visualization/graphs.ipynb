# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [20, 40, 60]
y = [10, 30, 50]
plt.plot(x, y)
plt.xlabel("Users count")
plt.ylabel("Request number")
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [20, 40, 60, 70, 80]
y = [10, 30, 50, 50, 50]
plt.plot(x, y)
plt.xlabel("Users count")
plt.ylabel("Respons number")
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [20, 30, 40, 50, 60, 70, 80]
y = [10, 10, 10, 15, 20, 30, 50]
plt.plot(x, y)
plt.xlabel("Users count")
plt.ylabel("Avg. Response time")
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [20, 30, 40, 50, 60, 70, 80, 90]
y = [10, 10, 10, 15, 20, 30, 30, 30]
axes = plt.gca()
axes.set_xlim([20, 90])
axes.set_ylim([5, 50])
plt.plot(x, y)
plt.xlabel("Users count")
plt.ylabel("Avg. Response time")
plt.show()
