# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.Graph()
G.add_edge(1,2)
G.add_edge(2,3)
G.add_edge(3,1)
G.add_edge(3,4)
G.add_edge(4,1)
G.add_edge(4,2)
nx.draw_networkx(G)
plt.show()
# Out:
# d:\python\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
G = nx.Graph()
G.add_edges_from([(1,2), (2,3),(3,4), (4,1), (5,4)])
nx.draw_networkx(G)
plt.show()

# %%
k = nx.fast_gnp_random_graph(15,0.40)
nx.draw_networkx(k)
plt.show()

# %%
G = nx.krackhardt_kite_graph()
nx.draw_networkx(G)
plt.show()
# Out:
# d:\python\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
print(nx.has_path(G, source=1, target=9))
print(nx.shortest_path(G, source=1, target=9))
print(nx.shortest_path_length(G, source=1, target=9))
# Out:
# True
# [1, 6, 7, 8, 9]
# 4

# %%
all_paths = list(nx.shortest_simple_paths(G, source=1, target=9))
for path in all_paths:
    print(path)
# Out:
# [1, 6, 7, 8, 9]
# [1, 0, 5, 7, 8, 9]
# [1, 6, 5, 7, 8, 9]
# [1, 3, 5, 7, 8, 9]
# [1, 4, 6, 7, 8, 9]
# [1, 3, 6, 7, 8, 9]
# [1, 0, 2, 5, 7, 8, 9]
# [1, 0, 5, 6, 7, 8, 9]
# [1, 6, 3, 5, 7, 8, 9]
# [1, 3, 5, 6, 7, 8, 9]
# [1, 4, 3, 5, 7, 8, 9]
# [1, 4, 6, 5, 7, 8, 9]
# [1, 3, 0, 5, 7, 8, 9]
# [1, 3, 6, 5, 7, 8, 9]
# [1, 0, 3, 5, 7, 8, 9]
# [1, 4, 3, 6, 7, 8, 9]
# [1, 3, 2, 5, 7, 8, 9]
# [1, 0, 3, 6, 7, 8, 9]
# [1, 3, 4, 6, 7, 8, 9]
# [1, 0, 2, 3, 5, 7, 8, 9]
# [1, 0, 2, 5, 6, 7, 8, 9]
# [1, 0, 5, 3, 6, 7, 8, 9]
# [1, 6, 4, 3, 5, 7, 8, 9]
# [1, 6, 3, 0, 5, 7, 8, 9]
# [1, 4, 3, 5, 6, 7, 8, 9]
# [1, 4, 6, 3, 5, 7, 8, 9]
# [1, 3, 0, 2, 5, 7, 8, 9]
# [1, 3, 0, 5, 6, 7, 8, 9]
# [1, 0, 3, 5, 6, 7, 8, 9]
# [1, 4, 3, 0, 5, 7, 8, 9]
# [1, 4, 3, 6, 5, 7, 8, 9]
# [1, 3, 2, 0, 5, 7, 8, 9]
# [1, 3, 2, 5, 6, 7, 8, 9]
# [1, 0, 3, 2, 5, 7, 8, 9]
# [1, 0, 3, 6, 5, 7, 8, 9]
# [1, 3, 4, 6, 5, 7, 8, 9]
# [1, 0, 2, 3, 6, 7, 8, 9]
# [1, 6, 3, 2, 5, 7, 8, 9]
# [1, 4, 3, 2, 5, 7, 8, 9]
# [1, 0, 3, 4, 6, 7, 8, 9]
# [1, 0, 2, 3, 5, 6, 7, 8, 9]
# [1, 0, 2, 5, 3, 6, 7, 8, 9]
# [1, 0, 5, 2, 3, 6, 7, 8, 9]
# [1, 0, 5, 3, 4, 6, 7, 8, 9]
# [1, 6, 4, 3, 0, 5, 7, 8, 9]
# [1, 6, 3, 0, 2, 5, 7, 8, 9]
# [1, 4, 6, 3, 0, 5, 7, 8, 9]
# [1, 3, 0, 2, 5, 6, 7, 8, 9]
# [1, 4, 3, 0, 2, 5, 7, 8, 9]
# [1, 4, 3, 0, 5, 6, 7, 8, 9]
# [1, 3, 2, 0, 5, 6, 7, 8, 9]
# [1, 0, 3, 2, 5, 6, 7, 8, 9]
# [1, 0, 2, 3, 4, 6, 7, 8, 9]
# [1, 0, 2, 3, 6, 5, 7, 8, 9]
# [1, 6, 3, 2, 0, 5, 7, 8, 9]
# [1, 4, 3, 2, 0, 5, 7, 8, 9]
# [1, 4, 3, 2, 5, 6, 7, 8, 9]
# [1, 0, 3, 4, 6, 5, 7, 8, 9]
# [1, 6, 4, 3, 2, 5, 7, 8, 9]
# [1, 4, 6, 3, 2, 5, 7, 8, 9]
# [1, 0, 2, 5, 3, 4, 6, 7, 8, 9]
# [1, 0, 5, 2, 3, 4, 6, 7, 8, 9]
# [1, 6, 4, 3, 0, 2, 5, 7, 8, 9]
# [1, 4, 6, 3, 0, 2, 5, 7, 8, 9]
# [1, 4, 3, 0, 2, 5, 6, 7, 8, 9]
# [1, 0, 2, 3, 4, 6, 5, 7, 8, 9]
# [1, 4, 3, 2, 0, 5, 6, 7, 8, 9]
# [1, 6, 4, 3, 2, 0, 5, 7, 8, 9]
# [1, 4, 6, 3, 2, 0, 5, 7, 8, 9]

# %%
paths = nx.all_pairs_shortest_path(G)
for path in paths:
    print(path)
# Out:
# (0, {0: [0], 1: [0, 1], 2: [0, 2], 3: [0, 3], 5: [0, 5], 4: [0, 1, 4], 6: [0, 1, 6], 7: [0, 5, 7], 8: [0, 5, 7, 8], 9: [0, 5, 7, 8, 9]})
# (1, {1: [1], 0: [1, 0], 3: [1, 3], 4: [1, 4], 6: [1, 6], 2: [1, 0, 2], 5: [1, 0, 5], 7: [1, 6, 7], 8: [1, 6, 7, 8], 9: [1, 6, 7, 8, 9]})
# (2, {2: [2], 0: [2, 0], 3: [2, 3], 5: [2, 5], 1: [2, 0, 1], 4: [2, 3, 4], 6: [2, 3, 6], 7: [2, 5, 7], 8: [2, 5, 7, 8], 9: [2, 5, 7, 8, 9]})
# (3, {3: [3], 0: [3, 0], 1: [3, 1], 2: [3, 2], 4: [3, 4], 5: [3, 5], 6: [3, 6], 7: [3, 5, 7], 8: [3, 5, 7, 8], 9: [3, 5, 7, 8, 9]})
# (4, {4: [4], 1: [4, 1], 3: [4, 3], 6: [4, 6], 0: [4, 1, 0], 2: [4, 3, 2], 5: [4, 3, 5], 7: [4, 6, 7], 8: [4, 6, 7, 8], 9: [4, 6, 7, 8, 9]})
# (5, {5: [5], 0: [5, 0], 2: [5, 2], 3: [5, 3], 6: [5, 6], 7: [5, 7], 1: [5, 0, 1], 4: [5, 3, 4], 8: [5, 7, 8], 9: [5, 7, 8, 9]})
# (6, {6: [6], 1: [6, 1], 3: [6, 3], 4: [6, 4], 5: [6, 5], 7: [6, 7], 0: [6, 1, 0], 2: [6, 3, 2], 8: [6, 7, 8], 9: [6, 7, 8, 9]})
# (7, {7: [7], 5: [7, 5], 6: [7, 6], 8: [7, 8], 0: [7, 5, 0], 2: [7, 5, 2], 3: [7, 5, 3], 1: [7, 6, 1], 4: [7, 6, 4], 9: [7, 8, 9]})
# (8, {8: [8], 7: [8, 7], 9: [8, 9], 5: [8, 7, 5], 6: [8, 7, 6], 0: [8, 7, 5, 0], 2: [8, 7, 5, 2], 3: [8, 7, 5, 3], 1: [8, 7, 6, 1], 4: [8, 7, 6, 4]})
# (9, {9: [9], 8: [9, 8], 7: [9, 8, 7], 5: [9, 8, 7, 5], 6: [9, 8, 7, 6], 0: [9, 8, 7, 5, 0], 2: [9, 8, 7, 5, 2], 3: [9, 8, 7, 5, 3], 1: [9, 8, 7, 6, 1], 4: [9, 8, 7, 6, 4]})
